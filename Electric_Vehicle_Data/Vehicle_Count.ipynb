# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import scipy.stats as linregress

# %%
csv_path = "Resources/raw_data/vehicle_count_2020.csv"
vehicle_df_2020 = pd.read_csv(csv_path)
vehicle_df_2020.head(1000)
# Out:
# /Users/girgs/opt/anaconda3/envs/google/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#          Date Zip Code Model Year      Fuel   Make   Duty  Vehicles
# 0    1/1/2020    90001       2007  Gasoline  ACURA  Light        15
# 1    1/1/2020    90002       2007  Gasoline  ACURA  Light        20
# 2    1/1/2020    90003       2007  Gasoline  ACURA  Light        29
# 3    1/1/2020    90004       2007  Gasoline  ACURA  Light        19
# 4    1/1/2020    90006       2007  Gasoline  ACURA  Light        15
# ..        ...      ...        ...       ...    ...    ...       ...
# 995  1/1/2020    95125       2007  Gasoline   AUDI  Light        27
# 996  1/1/2020    95126       2007  Gasoline   AUDI  Light        13
# 997  1/1/2020    95127       2007  Gasoline   AUDI  Light        23
# ...

# %%
vehicle_df_2020.groupby(["Model Year" , "Fuel"])[["Vehicles"]].sum()
# Out:
#                                      Vehicles
# Model Year Fuel
# 2007       Battery Electric                 1
#            Diesel and Diesel Hybrid     48821
#            Flex-Fuel                    61587
#            Gasoline                   1186177
#            Hybrid Gasoline              68151
# ...                                       ...
# Unk        Battery Electric                 2
#            Diesel and Diesel Hybrid       191
#            Gasoline                      2766
#            Natural Gas                      4
#            Other                            3
#
# [141 rows x 1 columns]

# %%
vehicle_df_2020["Registration Year"] = '2020'
vehicle_df_2020
# Out:
#             Date Zip Code Model Year      Fuel   Make   Duty  Vehicles  \
# 0       1/1/2020    90001       2007  Gasoline  ACURA  Light        15
# 1       1/1/2020    90002       2007  Gasoline  ACURA  Light        20
# 2       1/1/2020    90003       2007  Gasoline  ACURA  Light        29
# 3       1/1/2020    90004       2007  Gasoline  ACURA  Light        19
# 4       1/1/2020    90006       2007  Gasoline  ACURA  Light        15
# ...          ...      ...        ...       ...    ...    ...       ...
# 602389  1/1/2020      OOS        Unk  Gasoline    Unk  Heavy        98
# 602390  1/1/2020    90012        Unk  Gasoline    Unk  Light        12
# 602391  1/1/2020    93065        Unk  Gasoline    Unk  Light        11
# 602392  1/1/2020    95762        Unk  Gasoline    Unk  Light        12
# 602393  1/1/2020      OOS        Unk  Gasoline    Unk  Light        52
#
#        Registration Year
# 0                   2020
# 1                   2020
# 2                   2020
# ...

# %%
csv_path = "Resources/raw_data/vehicle_data_2018.csv"
vehicle_df_2018 = pd.read_csv(csv_path)
vehicle_df_2018.head(1000)
# Out:
# /Users/girgs/opt/anaconda3/envs/google/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#           Date Zip Code Model Year                      Fuel       Make  \
# 0    10/1/2018    90000       2006                  Gasoline  OTHER/UNK
# 1    10/1/2018    90000       2014                  Gasoline  OTHER/UNK
# 2    10/1/2018    90000       2016                  Gasoline  OTHER/UNK
# 3    10/1/2018    90000       2017                  Gasoline  OTHER/UNK
# 4    10/1/2018    90000      <2006  Diesel and Diesel Hybrid  OTHER/UNK
# ..         ...      ...        ...                       ...        ...
# 995  10/1/2018    90003       2010                  Gasoline       FORD
# 996  10/1/2018    90003       2010                  Gasoline      HONDA
# ...

# %%
vehicle_df_2018["Registration Year"] = '2018'
vehicle_df_2018
# Out:
#              Date Zip Code Model Year                      Fuel       Make  \
# 0       10/1/2018    90000       2006                  Gasoline  OTHER/UNK
# 1       10/1/2018    90000       2014                  Gasoline  OTHER/UNK
# 2       10/1/2018    90000       2016                  Gasoline  OTHER/UNK
# 3       10/1/2018    90000       2017                  Gasoline  OTHER/UNK
# 4       10/1/2018    90000      <2006  Diesel and Diesel Hybrid  OTHER/UNK
# ...           ...      ...        ...                       ...        ...
# 586228  10/1/2018    Other      <2006           Hybrid Gasoline     TOYOTA
# 586229  10/1/2018    Other      <2006               Natural Gas  OTHER/UNK
# 586230  10/1/2018    Other      <2006               Natural Gas  OTHER/UNK
# 586231  10/1/2018    Other      <2006                     Other  OTHER/UNK
# 586232  10/1/2018    Other      <2006                     Other  OTHER/UNK
#
#          Duty  Vehicles Registration Year
# ...

# %%
vehicle_df_df = pd.concat([vehicle_df_2020, vehicle_df_2018])
vehicle_df_df
# Out:
#              Date Zip Code Model Year             Fuel       Make   Duty  \
# 0        1/1/2020    90001       2007         Gasoline      ACURA  Light
# 1        1/1/2020    90002       2007         Gasoline      ACURA  Light
# 2        1/1/2020    90003       2007         Gasoline      ACURA  Light
# 3        1/1/2020    90004       2007         Gasoline      ACURA  Light
# 4        1/1/2020    90006       2007         Gasoline      ACURA  Light
# ...           ...      ...        ...              ...        ...    ...
# 586228  10/1/2018    Other      <2006  Hybrid Gasoline     TOYOTA  Light
# 586229  10/1/2018    Other      <2006      Natural Gas  OTHER/UNK  Heavy
# 586230  10/1/2018    Other      <2006      Natural Gas  OTHER/UNK  Light
# 586231  10/1/2018    Other      <2006            Other  OTHER/UNK  Heavy
# 586232  10/1/2018    Other      <2006            Other  OTHER/UNK  Light
#
#         Vehicles Registration Year
# 0             15              2020
# ...

# %%
vehicle_df_df.to_csv("Resources/raw_data/raw_vehicle_data.csv", index=False)

# %%
vehicle_df_df.groupby(["Model Year" , "Fuel","Registration Year"])[["Vehicles"]].sum().head(100)
# Out:
#                                                        Vehicles
# Model Year Fuel                     Registration Year
# 2007       Battery Electric         2020                      1
#            Diesel and Diesel Hybrid 2020                  48821
#            Flex-Fuel                2020                  61587
#            Gasoline                 2020                1186177
#            Hybrid Gasoline          2020                  68151
# ...                                                         ...
# 2006       Other                    2018                    106
# 2007       Battery Electric         2018                    652
#            Diesel and Diesel Hybrid 2018                  54312
#            Flex-Fuel                2018                  68636
#            Gasoline                 2018                1265759
#
# [100 rows x 1 columns]
