# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import scipy.stats as linregress

# %%
csv_path = "Resources/api_all_years_carbon_monoxide.csv"
co_allyears_df = pd.read_csv(csv_path)
#co_allyears_df.head()
co_allyears_df.columns
# Out:
# Index(['Unnamed: 0', 'state_code', 'county_code', 'site_number',
#        'parameter_code', 'poc', 'latitude', 'longitude', 'datum', 'parameter',
#        'sample_duration', 'pollutant_standard', 'date_local',
#        'units_of_measure', 'event_type', 'observation_count',
#        'observation_percent', 'validity_indicator', 'arithmetic_mean',
#        'first_max_value', 'first_max_hour', 'aqi', 'method_code', 'method',
#        'local_site_name', 'site_address', 'state', 'county', 'city',
#        'cbsa_code', 'cbsa', 'date_of_last_change', 'year'],
#       dtype='object')

# %%
#co_allyears_df.drop(columns = ["poc" , "parameter_code" , "method" , "sample_duration" , "validity_indicator" ,"event_type", "pollutant_standard" , 
                               #"observation_percent" ,"" ])

co_columns_drop = co_allyears_df.drop(columns = ['county_code', 'site_number',
        'parameter_code', 'poc', 'latitude', 'longitude', 'datum', 'parameter',
        'sample_duration', 'pollutant_standard', 'event_type', 'observation_count',
        'observation_percent', 'validity_indicator',
        'first_max_value', 'first_max_hour', 'aqi', 'method_code', 'method',
        'local_site_name','cbsa_code', 'cbsa', 'date_of_last_change', 'site_address' ,])\
        .query('year != 2019')

# %%
co_columns_drop
# Out:
#         Unnamed: 0  state_code  date_local   units_of_measure  \
# 0                0           6  2009-12-31  Parts per million
# 1                1           6  2009-12-31  Parts per million
# 2                2           6  2009-12-30  Parts per million
# 3                3           6  2009-12-30  Parts per million
# 4                4           6  2009-12-29  Parts per million
# ...            ...         ...         ...                ...
# 506676      506676           6  2018-01-04  Parts per million
# 506677      506677           6  2018-01-03  Parts per million
# 506678      506678           6  2018-01-02  Parts per million
# 506679      506679           6  2018-01-05  Parts per million
# 506680      506680           6  2018-04-01  Parts per million
#
#         arithmetic_mean       state         county           city  year
# 0              0.283333  California  Santa Barbara    Santa Maria  2009
# 1              0.291304  California  Santa Barbara    Santa Maria  2009
# 2              0.245833  California  Santa Barbara    Santa Maria  2009
# 3              0.260870  California  Santa Barbara    Santa Maria  2009
# 4              0.375000  California  Santa Barbara    Santa Maria  2009
# ...                 ...         ...            ...            ...   ...
# 506676         0.100000  California       Humboldt  Not in a city  2018
# 506677         0.130000  California       Humboldt  Not in a city  2018
# 506678         0.325000  California       Humboldt  Not in a city  2018
# 506679         0.104545  California       Humboldt  Not in a city  2018
# 506680         0.200000  California           Napa           Napa  2018
#
# [506681 rows x 9 columns]

# %%
co_allyears_df.groupby('year').mean()['arithmetic_mean'].plot(kind='line')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
#county_sort_df = co_allyears_df.groupby(['county', 'year'])['arithmetic_mean'].mean()
#county_sort_df.head(30)

# %%
#ax = county_sort_df.plot(kind='line', x= 'year', y= 'arithmetic_mean')
fig, ax = plt.subplots()
county_sort_df.groupby('county').plot(x='year', y='arithmetic_mean', ax=ax, legend=True)
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
#need to clean up above visualization
#value in breaking out percentage of each county of overall output?
